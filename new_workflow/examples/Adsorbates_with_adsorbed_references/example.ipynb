# %%
import sys
sys.path.append('../../')
from data.dft_data import adsorbate, adsorbate_list, long_description
from data.reference_data import reference_dict
from data.slab_data import slab_dict
from adsorbate import Adsorbate, Adsorbates

# %%
OXCXCH2 = Adsorbate(adsorbate, reference_dict, slab_dict, long_description)

# %%
OXCXCH2.plot_NASA7_fit()

# %%
RMG_string = OXCXCH2.get_RMG_thermo_database_entry(index=1)
print(RMG_string)
# Out:
# entry(
#     index = 1,
#     label = "OXCXCH2",
#     molecule =
# """
#
# 1 X u0 p0 c0 {3,S}
# 2 X u0 p0 c0 {4,S}
# 3 C u0 p0 c0 {1,S} {4,S} {5,D}
# 4 C u0 p0 c0 {2,S} {3,S} {6,S} {7,S}
# 5 O u0 p2 c0 {3,D}
# 6 H u0 p0 c0 {4,S}
# 7 H u0 p0 c0 {4,S}
# """,
#     thermo = NASA(
#         polynomials = [
#             NASAPolynomial(coeffs=[-0.6497117249237396, 0.03554659990718592, -4.414269779955767e-05, 2.9390359305178724e-08, -8.001765916532122e-12, -24867.665024150916, 1.8076763055253844], Tmin=(298.0,'K'),Tmax=(1000.0, 'K')),
#             NASAPolynomial(coeffs=[12.113681847665207, -0.007676997669967362, 1.3787877482169512e-05, -7.421194660794445e-09, 1.3394167722781966e-12, -27994.799615007716, -62.165190770507756], Tmin=(1000.0,'K'), Tmax=(2000.0, 'K')),
#         ],
#         Tmin = (298.0,'K'),
#         Tmax = (2000.0,'K'),
#     ),
# longDesc = u"""
# Calculated by [author] at [institution] using statistical mechanics methods within the class Adsorbate.
# ...

# %%
ads_list = Adsorbates(adsorbate_list,reference_dict, slab_dict, long_description)

# %%
ads_list.plot_NASA7_fits()

# %%
rmg_entries = ads_list.get_RMG_thermo_database_entries()
print(rmg_entries)
# Out:
# entry(
#     index = 1,
#     label = "OXCXCH2",
#     molecule =
# """
#
# 1 X u0 p0 c0 {3,S}
# 2 X u0 p0 c0 {4,S}
# 3 C u0 p0 c0 {1,S} {4,S} {5,D}
# 4 C u0 p0 c0 {2,S} {3,S} {6,S} {7,S}
# 5 O u0 p2 c0 {3,D}
# 6 H u0 p0 c0 {4,S}
# 7 H u0 p0 c0 {4,S}
# """,
#     thermo = NASA(
#         polynomials = [
#             NASAPolynomial(coeffs=[-0.6497117249237396, 0.03554659990718592, -4.414269779955767e-05, 2.9390359305178724e-08, -8.001765916532122e-12, -24867.665024150916, 1.8076763055253844], Tmin=(298.0,'K'),Tmax=(1000.0, 'K')),
#             NASAPolynomial(coeffs=[12.113681847665207, -0.007676997669967362, 1.3787877482169512e-05, -7.421194660794445e-09, 1.3394167722781966e-12, -27994.799615007716, -62.165190770507756], Tmin=(1000.0,'K'), Tmax=(2000.0, 'K')),
#         ],
#         Tmin = (298.0,'K'),
#         Tmax = (2000.0,'K'),
#     ),
# longDesc = u"""
# Calculated by [author] at [institution] using statistical mechanics methods within the class Adsorbate.
# ...
